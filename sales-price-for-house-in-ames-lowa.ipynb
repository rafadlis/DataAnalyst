# %% [markdown]
# <a href="https://www.kaggle.com/code/rrahmatfadlisadikin/sales-price-for-house-in-ames-lowa?scriptVersionId=117608032" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/house-prices-advanced-regression-techniques/sample_submission.csv
# /kaggle/input/house-prices-advanced-regression-techniques/data_description.txt
# /kaggle/input/house-prices-advanced-regression-techniques/train.csv
# /kaggle/input/house-prices-advanced-regression-techniques/test.csv

# %% [markdown]
# # Sales price for House in Ames, Lowa
# ![Ames, Lowa](https://www.worldatlas.com/r/w960-q80/upload/24/cc/dd/shutterstock-2182103719.jpg)
# Source: [Worldtlas - Ames, Lowa](https://www.worldatlas.com/cities/ames-iowa.html)

# %%
# import the important python packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Styling matplotlib using kaggle style
## Importing package 
plt.style.use('default')
from matplotlib import rcParams as style # for make custom matplotlib style
from cycler import cycler # for make color pallete

## styling typography
font_family = 'sans-serif'
font_sansserif = ['Inter',]
fig_facecolor = 'white'
fig_titlesize = 18

style['font.family'] = font_family
style['font.sans-serif'] = font_sansserif
style['figure.facecolor'] = fig_facecolor
style['figure.titlesize'] = fig_titlesize

## Coloring
the_color = [
    '#20BEFF', # blue
    '#DEE0E1', # green
    '#fae041', # yellow
    '#f1f3f4', # purple
    '#ff5c19', # orange
    '#e5cf4a', # gold
]
black_color = '#202124'
gray_color = '#f1f3f4'
style['axes.facecolor'] = gray_color
style['grid.color'] = black_color
style['axes.prop_cycle'] = cycler('color', the_color)

# %% [markdown]
# ***
# ## Background
# The Price of a home is one of the most concerning things when someone wants to buy a house. After talking to someone about buying a house, Most people discuss the price first than anything else. They often check the price first and try to match the features they want with the house.
#
# We know the price is important but people often wrongly guess the price because they are just using their instinct. But that problem can be solved by using machine learning. Machine learning can almost solve any problem but it needs a data, lot of data.
#
# So here we have two data sets about the house in Ames, Lowa, United States to make house price predictions using Machine Learning. Machine Learning can be used by someone who wants to know the price of a house in Ames but the price is never recorded.
#
# <div class="alert alert-block alert-warning">
#     <b>⚠️ Warning:</b> <br>
#     The data is not up to date. So, the prediction may not accurate for this time. Bear in mind, This data used for Machine Learning competition/training purpose.
# </div>
#
# ## Objective
# Make a Machine Learning Model to predict the price of house in Ames with axisting data.
#
# ## Data Source
# The Ames Housing dataset was compiled by Dean De Cock for use in data science education. It's an incredible alternative for data scientists looking for a modernized and expanded version of the often cited Boston Housing dataset.
#
# The data is split into two parts for make a training and testing data set with same columns but there are no price column in the test data.

# %% [markdown]
# # Methodology
# ***

# %% [markdown]
# # 1. Exploratory Data Analysis <a id='sec1'></a>
# ___

# %% [markdown]
# ## 1.1 Data Characteristic

# %%
test = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/test.csv')
train = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/train.csv')
print('Test Table')
print('Total Row: ' + str(test.shape[0]) + ', Total Column: ' + str(test.shape[1]))
print('\nTrain Table\n' + 'Total Row: ' + str(train.shape[0]) + ', Total Column: ' + str(train.shape[1]))
# Out:
# Test Table
# Total Row: 1459, Total Column: 80
#
# Train Table
# Total Row: 1460, Total Column: 81

# %% [markdown]
# As expected, the total column from both table is not match because the test table is not contain price column that supposed to be find by us.

# %% [markdown]
# # 2. Building The Machine Learning Model
# ___

# %% [markdown]
# # 3. Implication & Limitations
# ___

# %% [markdown]
# # 4. References & Resource
# ___

# %% [markdown]
# # 5. Appendix
# ___
